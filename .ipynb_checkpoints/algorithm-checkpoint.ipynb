# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.svm import SVC
from gensim.models import LdaModel, LsiModel, TfidfModel, Word2Vec, FastText, Doc2Vec
from gensim.corpora.dictionary import Dictionary
import re
import string
import nltk
nltk.download('wordnet')
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer 
from nltk.corpus import stopwords
from pymorphy3 import MorphAnalyzer

from sklearn.decomposition import TruncatedSVD
from sklearn.cluster import KMeans

import matplotlib.pyplot as plt
from sklearn.metrics import silhouette_score
from gensim.matutils import corpus2dense
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/portnovaxenia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/portnovaxenia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
nltk.__version__
# Out:
# '3.8.1'

# %%
df = pd.read_csv('legal_text_corpus.csv')
df.columns = ['Name','Link','Text','Comment','Data']
df
# Out:
#                                                    Name  \
# 0     Указ временно исполняющего обязанности главы Д...
# 1     Постановление Конституционного Суда Российской...
# 2     Постановление Пленума Верховного Суда Российск...
# 3     Федеральный закон от 21 ноября 2022 г. N 443-Ф...
# 4     Федеральный закон от 21 ноября 2022 г. N 448-Ф...
# ...                                                 ...
# 2958  Постановление о совершенствовании госрегулиров...
# 2959  Правила оплаты проезда осужденных, самостоятел...
# 2960  Изменения в постановление правительства о него...
# 2961  Постановление Главного госсанврача о надзоре з...
# 2962   Закон о патентных поверенных — Российская газета
#
#                                                    Link  \
# 0     https://rg.ru/documents/2022/11/28/dnr-ukaz37-...
# 1     https://rg.ru/documents/2022/11/25/document-ob...
# 2     https://rg.ru/documents/2022/11/25/document-pl...
# 3     https://rg.ru/documents/2022/11/24/document-na...
# 4     https://rg.ru/documents/2022/11/24/document-by...
# ...                                                 ...
# 2958        https://rg.ru/2009/08/14/lekarstva-dok.html
# 2959          https://rg.ru/2009/08/12/pravila-dok.html
# 2960   https://rg.ru/2009/08/07/sysk-izmenenia-dok.html
# 2961              https://rg.ru/2009/08/05/bad-dok.html
# 2962       https://rg.ru/2008/12/31/poverennie-dok.html
#
#                                                    Text  \
# 0     1. Внести в Указ временно исполняющего обязанн...
# 1     Именем Российской Федерации  Конституционный С...
# 2     В целях обеспечения единства практики применен...
# 3     Принят Государственной Думой 10 ноября 2022 го...
# 4     Принят Государственной Думой 10 ноября 2022 го...
# ...                                                 ...
# 2958  Правительство Российской Федерации постановляе...
# 2959  В соответствии с частью второй статьи 751 Угол...
# 2960  Правительство Российской Федерации постановляе...
# 2961  Зарегистрирован в Минюсте РФ 10 июля 2009 г.  ...
# 2962  Принят Государственной Думой 24 декабря 2008 г...
#
#                                                 Comment        Data
# 0     Врио главы ДНР Денис Пушилин подписал указ об ...  2022-11-28
# 1     Бессрочный запрет на профессию для адвокатов, ...  2022-11-25
# 2     Пленум Верховного суда России утвердил постано...  2022-11-25
# 3     На сладкую газировку с 1 июля 2023 года введут...  2022-11-24
# 4     Приостановленное в этом году бюджетное правило...  2022-11-24
# ...                                                 ...         ...
# 2958  Производители жизненно необходимых и важнейших...  2009-08-14
# 2959  Правительство утвердило новые правила, как опл...  2009-08-12
# 2960  Частные охранники и детективы должны будут про...  2009-08-20
# 2961  В России усилят контроль за производством и об...  2009-08-20
# 2962  В этом году деятельность патентных поверенных ...  2008-12-31
#
# [2963 rows x 5 columns]

# %%
def process_text(text):
    stop_words = set(stopwords.words('russian'))
    morph = MorphAnalyzer()

    # Токенизация текста
    tokens = word_tokenize(text)
    # Оставляем только буквенные токены
    tokens = [word for word in tokens if word.isalpha()]
    # Приводим все токены к нижнему регистру
    tokens = [word.lower() for word in tokens]
    # Удаляем стоп-слова
    tokens = [word for word in tokens if not word in stop_words]
    # Лемматизация токенов
    tokens = [morph.normal_forms(word)[0] for word in tokens]

    return tokens

# %%
def join_list(tab):
    return " ".join((''.join(l) for l in tab))

# %%
tokens = df['Text']
tokens = tokens.apply(lambda token: process_text(token))
tokens = [[token for token in sublist if token not in ['ст', 'n']] for sublist in tokens]
tokens = pd.Series(tokens)
df['Tokens'] = tokens
df["Text_preprocessed"] = tokens.apply(join_list)

# %%
mydict = Dictionary(df['Tokens'])
corpus = [mydict.doc2bow(text) for text in df['Tokens']]
tf_model = TfidfModel(corpus) 
corpus_tf = tf_model[corpus]  
lsi_model = LsiModel(corpus_tf, id2word=mydict, num_topics=30)

# %%
lsi_model.show_topics(num_topics=5, num_words=10, formatted=False)
# Out:
# [(0,
#   [('слово', 0.22498367942784991),
#    ('тысяча', 0.12751845265292266),
#    ('статья', 0.1264731855970039),
#    ('часть', 0.11759718195925586),
#    ('военный', 0.1172779193092611),
#    ('административный', 0.11350828315664478),
#    ('суд', 0.10730627121350061),
#    ('налоговый', 0.10351962948115191),
#    ('орган', 0.10094409411404234),
#    ('служба', 0.09997412199718289)]),
#  (1,
#   [('военный', -0.464009564928743),
#    ('тысяча', 0.37474864721511636),
#    ('служба', -0.3060592118688893),
#    ('воинский', -0.2322372376489784),
#    ('призыв', -0.20754221965100295),
#    ('слово', 0.18339487531263626),
#    ('административный', 0.17468331491326528),
#    ('рубль', 0.16488525677461552),
#    ('военнослужащий', -0.11239182933466745),
#    ('штраф', 0.11219401947818815)]),
#  (2,
#   [('тысяча', 0.4309019262323266),
#    ('военный', 0.3985341333362262),
#    ('служба', 0.22564802060541286),
#    ('воинский', 0.2109308831241841),
#    ('призыв', 0.19723562275508663),
#    ('административный', 0.16266189377528967),
#    ('слово', 0.16138399844370352),
#    ('рубль', 0.14326809149955427),
#    ('штраф', 0.11381364162069847),
#    ('правонарушение', 0.09962024515732158)]),
#  (3,
#   [('суд', 0.3019884144568605),
#    ('налоговый', -0.2352664515589378),
#    ('слово', -0.16679156503698347),
#    ('бюджет', -0.16627236724980649),
#    ('рф', 0.15729084544229133),
#    ('дело', 0.15186175562817122),
#    ('конституционный', 0.15009103566346074),
#    ('судебный', 0.14406546983573099),
#    ('тыс', -0.1411381351320953),
#    ('налог', -0.13510867194124748)]),
#  (4,
#   [('инфекция', 0.2618567006660469),
#    ('коронавирусный', 0.2572508764478296),
#    ('тысяча', 0.24099010188784922),
#    ('суд', -0.22733069302814662),
#    ('налоговый', -0.20455840109588405),
#    ('медицинский', 0.13370634524393854),
#    ('область', 0.12502357199219738),
#    ('налог', -0.11589965922709461),
#    ('конституционный', -0.11244900975222173),
#    ('указ', 0.1117021232618938)])]

# %%
text = lsi_model[corpus]

# %%
topic_ids = [max(vector, key=lambda item: item[1])[0] for vector in text]

# %%
df['Topic_byText'] = topic_ids

# %%
df['Topic_byText'].value_counts()
# Out:
# 0     2662
# 1       60
# 10      45
# 18      27
# 2       26
# 8       25
# 12      25
# 6       24
# 15      17
# 3       17
# 7       10
# 5       10
# 19      10
# 13       3
# 17       2
# Name: Topic_byText, dtype: int64

# %%
feature_matrix = corpus2dense(lsi_model[corpus], num_terms=lsi_model.num_topics).T
k_values = range(2, 50)

sse_values = []

for k in k_values:
    kmeans_model = KMeans(n_clusters=k, random_state=42, n_init = 10)
    kmeans_model.fit(feature_matrix)
    sse_values.append(kmeans_model.inertia_)

plt.plot(k_values, sse_values, 'bo-')
plt.xlabel('Number of Clusters')
plt.ylabel('SSE')
plt.title('Elbow Method')
plt.show()

# %%
name = df['Name'].apply(lambda text: process_text(text))
name = pd.Series(name)
name = name.apply(join_list)

tfidf_vectorizer = TfidfVectorizer(max_df=0.8, min_df=5)
tfidf_matrix = tfidf_vectorizer.fit_transform(name)
lsi_model = TruncatedSVD(n_components=100)  
lsi_vectors = lsi_model.fit_transform(tfidf_matrix)

silhouette_scores = []
max_clusters = 20
for n_clusters in range(2, max_clusters+1):
    kmeans = KMeans(n_clusters=n_clusters, random_state=42, n_init=10)
    cluster_labels = kmeans.fit_predict(lsi_vectors)
    silhouette_avg = silhouette_score(lsi_vectors, cluster_labels)
    silhouette_scores.append(silhouette_avg)

plt.plot(range(2, max_clusters+1), silhouette_scores, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score vs Number of Clusters')
plt.show()

# %%
kmeans = KMeans(n_clusters=12, random_state=42, n_init = 10)
cluster_labels = kmeans.fit_predict(lsi_vectors)

df['Topic_byName'] = cluster_labels
df
# Out:
#                                                    Name  \
# 0     Указ временно исполняющего обязанности главы Д...
# 1     Постановление Конституционного Суда Российской...
# 2     Постановление Пленума Верховного Суда Российск...
# 3     Федеральный закон от 21 ноября 2022 г. N 443-Ф...
# 4     Федеральный закон от 21 ноября 2022 г. N 448-Ф...
# ...                                                 ...
# 2958  Постановление о совершенствовании госрегулиров...
# 2959  Правила оплаты проезда осужденных, самостоятел...
# 2960  Изменения в постановление правительства о него...
# 2961  Постановление Главного госсанврача о надзоре з...
# 2962   Закон о патентных поверенных — Российская газета
#
#                                                    Link  \
# 0     https://rg.ru/documents/2022/11/28/dnr-ukaz37-...
# 1     https://rg.ru/documents/2022/11/25/document-ob...
# 2     https://rg.ru/documents/2022/11/25/document-pl...
# 3     https://rg.ru/documents/2022/11/24/document-na...
# 4     https://rg.ru/documents/2022/11/24/document-by...
# ...                                                 ...
# 2958        https://rg.ru/2009/08/14/lekarstva-dok.html
# 2959          https://rg.ru/2009/08/12/pravila-dok.html
# 2960   https://rg.ru/2009/08/07/sysk-izmenenia-dok.html
# 2961              https://rg.ru/2009/08/05/bad-dok.html
# 2962       https://rg.ru/2008/12/31/poverennie-dok.html
#
#                                                    Text  \
# 0     1. Внести в Указ временно исполняющего обязанн...
# 1     Именем Российской Федерации  Конституционный С...
# 2     В целях обеспечения единства практики применен...
# 3     Принят Государственной Думой 10 ноября 2022 го...
# 4     Принят Государственной Думой 10 ноября 2022 го...
# ...                                                 ...
# 2958  Правительство Российской Федерации постановляе...
# 2959  В соответствии с частью второй статьи 751 Угол...
# 2960  Правительство Российской Федерации постановляе...
# 2961  Зарегистрирован в Минюсте РФ 10 июля 2009 г.  ...
# 2962  Принят Государственной Думой 24 декабря 2008 г...
#
#                                                 Comment        Data  \
# 0     Врио главы ДНР Денис Пушилин подписал указ об ...  2022-11-28
# 1     Бессрочный запрет на профессию для адвокатов, ...  2022-11-25
# 2     Пленум Верховного суда России утвердил постано...  2022-11-25
# 3     На сладкую газировку с 1 июля 2023 года введут...  2022-11-24
# 4     Приостановленное в этом году бюджетное правило...  2022-11-24
# ...                                                 ...         ...
# 2958  Производители жизненно необходимых и важнейших...  2009-08-14
# 2959  Правительство утвердило новые правила, как опл...  2009-08-12
# 2960  Частные охранники и детективы должны будут про...  2009-08-20
# 2961  В России усилят контроль за производством и об...  2009-08-20
# 2962  В этом году деятельность патентных поверенных ...  2008-12-31
#
#                                                  Tokens  \
# 0     [внести, указ, временно, исполнять, обязанност...
# 1     [имя, российский, федерация, конституционный, ...
# 2     [цель, обеспечение, единство, практика, примен...
# 3     [принять, государственный, дума, ноябрь, год, ...
# 4     [принять, государственный, дума, ноябрь, год, ...
# ...                                                 ...
# 2958  [правительство, российский, федерация, постано...
# 2959  [соответствие, часть, второй, статья, кодекс, ...
# 2960  [правительство, российский, федерация, постано...
# 2961  [зарегистрировать, минюст, рф, июль, регистрац...
# 2962  [принять, государственный, дума, декабрь, год,...
#
#                                       Text_preprocessed  Topic_byText  \
# 0     внести указ временно исполнять обязанность гла...            10
# 1     имя российский федерация конституционный суд р...             0
# 2     цель обеспечение единство практика применение ...             0
# 3     принять государственный дума ноябрь год одобри...             0
# 4     принять государственный дума ноябрь год одобри...             0
# ...                                                 ...           ...
# 2958  правительство российский федерация постановлят...             0
# 2959  соответствие часть второй статья кодекс россий...             0
# 2960  правительство российский федерация постановлят...             0
# 2961  зарегистрировать минюст рф июль регистрационны...             0
# 2962  принять государственный дума декабрь год одобр...             0
#
#              Action                                            Expired  \
# 0               NaN                                                NaN
# 1      Рассмотрение                                                NaN
# 2       Разъяснение                                                NaN
# 3         Изменение                                                NaN
# 4         Изменение  Федерального закона "Об особенностях эмиссии и...
# ...             ...                                                ...
# 2958    Разъяснение                                                NaN
# 2959            NaN                                                NaN
# 2960            NaN                                                NaN
# 2961  Постановление                                                NaN
# 2962            NaN                                                NaN
#
#       Topic_byName
# 0                1
# 1                2
# 2               11
# 3                8
# 4                4
# ...            ...
# 2958             1
# 2959             1
# 2960             1
# 2961             1
# 2962             9
#
# [2963 rows x 11 columns]

# %%
df['Topic_byName'].value_counts()
# Out:
# 1     1322
# 9      476
# 4      287
# 10     183
# 5      165
# 8      114
# 2      110
# 3      101
# 11      99
# 6       44
# 0       38
# 7       24
# Name: Topic_byName, dtype: int64

# %%
import spacy
import ru_core_news_sm

nlp = ru_core_news_sm.load()

def extract_organization(text):
    doc = nlp(text)
    organizations = [ent.text for ent in doc.ents if ent.label_ == 'ORG']
    return organizations[0] if organizations else None

df['Author'] = df['Text'].apply(extract_organization)


df
# Out:
#                                                    Name  \
# 0     Указ временно исполняющего обязанности главы Д...
# 1     Постановление Конституционного Суда Российской...
# 2     Постановление Пленума Верховного Суда Российск...
# 3     Федеральный закон от 21 ноября 2022 г. N 443-Ф...
# 4     Федеральный закон от 21 ноября 2022 г. N 448-Ф...
# ...                                                 ...
# 2958  Постановление о совершенствовании госрегулиров...
# 2959  Правила оплаты проезда осужденных, самостоятел...
# 2960  Изменения в постановление правительства о него...
# 2961  Постановление Главного госсанврача о надзоре з...
# 2962   Закон о патентных поверенных — Российская газета
#
#                                                    Link  \
# 0     https://rg.ru/documents/2022/11/28/dnr-ukaz37-...
# 1     https://rg.ru/documents/2022/11/25/document-ob...
# 2     https://rg.ru/documents/2022/11/25/document-pl...
# 3     https://rg.ru/documents/2022/11/24/document-na...
# 4     https://rg.ru/documents/2022/11/24/document-by...
# ...                                                 ...
# 2958        https://rg.ru/2009/08/14/lekarstva-dok.html
# 2959          https://rg.ru/2009/08/12/pravila-dok.html
# 2960   https://rg.ru/2009/08/07/sysk-izmenenia-dok.html
# 2961              https://rg.ru/2009/08/05/bad-dok.html
# 2962       https://rg.ru/2008/12/31/poverennie-dok.html
#
#                                                    Text  \
# 0     1. Внести в Указ временно исполняющего обязанн...
# 1     Именем Российской Федерации  Конституционный С...
# 2     В целях обеспечения единства практики применен...
# 3     Принят Государственной Думой 10 ноября 2022 го...
# 4     Принят Государственной Думой 10 ноября 2022 го...
# ...                                                 ...
# 2958  Правительство Российской Федерации постановляе...
# 2959  В соответствии с частью второй статьи 751 Угол...
# 2960  Правительство Российской Федерации постановляе...
# 2961  Зарегистрирован в Минюсте РФ 10 июля 2009 г.  ...
# 2962  Принят Государственной Думой 24 декабря 2008 г...
#
#                                                 Comment        Data  \
# 0     Врио главы ДНР Денис Пушилин подписал указ об ...  2022-11-28
# 1     Бессрочный запрет на профессию для адвокатов, ...  2022-11-25
# 2     Пленум Верховного суда России утвердил постано...  2022-11-25
# 3     На сладкую газировку с 1 июля 2023 года введут...  2022-11-24
# 4     Приостановленное в этом году бюджетное правило...  2022-11-24
# ...                                                 ...         ...
# 2958  Производители жизненно необходимых и важнейших...  2009-08-14
# 2959  Правительство утвердило новые правила, как опл...  2009-08-12
# 2960  Частные охранники и детективы должны будут про...  2009-08-20
# 2961  В России усилят контроль за производством и об...  2009-08-20
# 2962  В этом году деятельность патентных поверенных ...  2008-12-31
#
#                                                  Tokens  \
# 0     [внести, указ, временно, исполнять, обязанност...
# 1     [имя, российский, федерация, конституционный, ...
# 2     [цель, обеспечение, единство, практика, примен...
# 3     [принять, государственный, дума, ноябрь, год, ...
# 4     [принять, государственный, дума, ноябрь, год, ...
# ...                                                 ...
# 2958  [правительство, российский, федерация, постано...
# 2959  [соответствие, часть, второй, статья, кодекс, ...
# 2960  [правительство, российский, федерация, постано...
# 2961  [зарегистрировать, минюст, рф, июль, регистрац...
# 2962  [принять, государственный, дума, декабрь, год,...
#
#                                       Text_preprocessed  Topic_byText  \
# 0     внести указ временно исполнять обязанность гла...            10
# 1     имя российский федерация конституционный суд р...             0
# 2     цель обеспечение единство практика применение ...             0
# 3     принять государственный дума ноябрь год одобри...             0
# 4     принять государственный дума ноябрь год одобри...             0
# ...                                                 ...           ...
# 2958  правительство российский федерация постановлят...             0
# 2959  соответствие часть второй статья кодекс россий...             0
# 2960  правительство российский федерация постановлят...             0
# 2961  зарегистрировать минюст рф июль регистрационны...             0
# 2962  принять государственный дума декабрь год одобр...             0
#
#              Action                                            Expired  \
# 0               NaN                                                NaN
# 1      Рассмотрение                                                NaN
# 2       Разъяснение                                                NaN
# 3         Изменение                                                NaN
# 4         Изменение  Федерального закона "Об особенностях эмиссии и...
# ...             ...                                                ...
# 2958    Разъяснение                                                NaN
# 2959            NaN                                                NaN
# 2960            NaN                                                NaN
# 2961  Постановление                                                NaN
# 2962            NaN                                                NaN
#
#       Topic_byName                                    Found_Law_Names  \
# 0                1
# 1                2
# 2               11  Об основах туристской деятельности в Российско...
# 3                8  Об особенностях исполнения обязательств по кре...
# 4                4  О соглашениях о разделе продукции, О драгоценн...
# ...            ...                                                ...
# 2958             1
# 2959             1
# 2960             1
# 2961             1  О санитарно-эпидемиологическом благополучии на...
# 2962             9                              О персональных данных
#
#                      Author
# 0                      None
# 1       Конституционный Суд
# 2           Верховного Суда
# 3     Государственной Думой
# 4     Государственной Думой
# ...                     ...
# 2958          Правительства
# 2959          Правительства
# 2960          Правительства
# 2961                Минюсте
# 2962  Государственной Думой
#
# [2963 rows x 13 columns]

# %%
len(df['Text'][3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 len(df['Text'][3])
#
# NameError: name 'df' is not defined

# %%
df.loc[df['Text'].str.contains('следующие изменения' or 'изменение' or 'Внести в', case=False), 'Action'] = 'Изменение'
df.loc[df['Text'].str.contains('разъяснения', case=False), 'Action'] = 'Разъяснение'
df.loc[df['Text'].str.contains('постановляю' or 'регулирует', case=False), 'Action'] = 'Постановление'
df.loc[df['Text'].str.contains('дело о проверке' or 'жалоба', case=False), 'Action'] = 'Рассмотрение'

# %%
df['Action'].value_counts()
# Out:
# Изменение        1112
# Постановление     271
# Разъяснение       196
# Рассмотрение      125
# Name: Action, dtype: int64

# %%
df['Text'][2962]
# Out:
# 0     [внести, указ, временно, исполнять, обязанност...
# 1     [имя, российский, федерация, конституционный, ...
# 2     [цель, обеспечение, единство, практика, примен...
# 3     [принять, государственный, дума, ноябрь, год, ...
# 4     [принять, государственный, дума, ноябрь, год, ...
# ...                                                 ...
# 2958  [правительство, российский, федерация, постано...
# 2959  [соответствие, часть, второй, статья, кодекс, ...
# 2960  [правительство, российский, федерация, постано...
# 2961  [зарегистрировать, минюст, рф, июль, регистрац...
# 2962  [принять, государственный, дума, декабрь, год,...
#
#                                       Text_preprocessed  Topic_byText  \
# 0     внести указ временно исполнять обязанность гла...            10
# 1     имя российский федерация конституционный суд р...             0
# 2     цель обеспечение единство практика применение ...             0
# 3     принять государственный дума ноябрь год одобри...             0
# 4     принять государственный дума ноябрь год одобри...             0
# ...                                                 ...           ...
# 2958  правительство российский федерация постановлят...             0
# 2959  соответствие часть второй статья кодекс россий...             0
# 2960  правительство российский федерация постановлят...             0
# 2961  зарегистрировать минюст рф июль регистрационны...             0
# 2962  принять государственный дума декабрь год одобр...             0
#
#              Action                                            Expired
# 0               NaN                                                NaN
# 1      Рассмотрение                                                NaN
# 2       Разъяснение                                                NaN
# 3         Изменение                                                NaN
# 4         Изменение  Федерального закона "Об особенностях эмиссии и...
# ...             ...                                                ...
# 2958    Разъяснение                                                NaN
# 2959            NaN                                                NaN
# 2960            NaN                                                NaN
# 2961  Постановление                                                NaN
# 2962            NaN                                                NaN
#
# [2963 rows x 10 columns]

# %%
import re

pattern = r'N\s+\d+-ФЗ\s+"(.*?)"'
pattern2 = r'пункт\s+\d+\s+статьи\s+\d+\s+части\s+\w+\s+(.*?)(?=\()'

df['Found_Law_Names'] = ''

for i, text in enumerate(df['Text']):
    matches = re.findall(pattern, text)
    filtered_matches = [match for match in matches if match not in df['Name'][i]]
    
    matches2 = re.findall(pattern2, text)
    filtered_matches.extend(matches2)
    
    if filtered_matches:
        df.at[i, 'Found_Law_Names'] = ', '.join(filtered_matches)

# %%
df['Found_Law_Names'][2]
# Out:
# 'Об основах туристской деятельности в Российской Федерации, Об исполнительном производстве, Об обязательном страховании гражданской ответственности владельцев транспортных средств, Об основах системы профилактики безнадзорности и правонарушений несовершеннолетних, Об обязательном социальном страховании от несчастных случаев на производстве и профессиональных заболеваний, Об основах охраны здоровья граждан Российской Федерации, О связи, О почтовой связи'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd


def find_duplicate_quotes_tfidf(df):
    # Initialize TF-IDF vectorizer
    vectorizer = TfidfVectorizer()

    # Fit and transform the text data
    tfidf_matrix = vectorizer.fit_transform(df['Text'])

    # Compute cosine similarity matrix
    similarity_matrix = cosine_similarity(tfidf_matrix)

    duplicates = []
    n_docs = len(df)

    # Iterate over each document
    for i in range(n_docs):
        # Find indices of documents with similarity score above a threshold (e.g., 0.9)
        duplicate_indices = [j for j in range(n_docs) if similarity_matrix[i, j] > 0.99 and i != j]

        if duplicate_indices:
            duplicate = {
                'Law Index': i,
                'Duplicate Indices': duplicate_indices,
                'Duplicate Text': df.iloc[i]['Text']
            }
            duplicates.append(duplicate)

    duplicates_df = pd.DataFrame(duplicates)
    return duplicates_df

duplicates_df = find_duplicate_quotes_tfidf(df)

# %%
duplicates_df
# Out:
#      Law Index Duplicate Indices  \
# 0            0             [266]
# 1            1             [169]
# 2            2             [170]
# 3            3             [171]
# 4            4             [172]
# ..         ...               ...
# 911       2534            [2323]
# 912       2668            [2835]
# 913       2732            [2736]
# 914       2736            [2732]
# 915       2835            [2668]
#
#                                         Duplicate Text
# 0    1. Внести в Указ временно исполняющего обязанн...
# 1    Именем Российской Федерации  Конституционный С...
# 2    В целях обеспечения единства практики применен...
# 3    Принят Государственной Думой 10 ноября 2022 го...
# 4    Принят Государственной Думой 10 ноября 2022 го...
# ..                                                 ...
# 911  Основные показатели социально-экономического п...
# 912  Зарегистрирован в Минюсте РФ 29 января 2010 г....
# 913  В соответствии с пунктом 5 статьи 181 Федераль...
# 914  В соответствии с пунктом 5 статьи 181 Федераль...
# 915  Зарегистрирован в Минюсте РФ 20 января 2009 г....
#
# [916 rows x 3 columns]

# %%
len(df['Text'][1])
# Out:
# 32711

# %%
duplicates_df['Duplicate Text'][1]
# Out:
# 'Именем Российской Федерации  Конституционный Суд Российской Федерации в составе Председателя B.Д.Зорькина, судей А.Ю.Бушева, Г.А.Гаджиева, Л.М.Жарковой, C.М.Казанцева, С.Д.Князева, А.Н.Кокотова, Л.О.Красавчиковой, С.П.Маврина, Н.В.Мельникова,  руководствуясь статьей 125 (пункт "а" части 4) Конституции Российской Федерации, пунктом 3 части первой, частями третьей и четвертой статьи 3, частью первой статьи 21, статьями 36, 471, 74, 86, 96, 97 и 99 Федерального конституционного закона "О Конституционном Суде Российской Федерации",  рассмотрел в заседании без проведения слушания дело о проверке конституционности абзаца второго пункта 3 статьи 17 Федерального закона "Об адвокатской деятельности и адвокатуре в Российской Федерации".  Поводом к рассмотрению дела явилась жалоба гражданина С.Г.Шалавина. Основанием к рассмотрению дела явилась обнаружившаяся неопределенность в вопросе о том, соответствует ли Конституции Российской Федерации оспариваемое заявителем законоположение.  Заслушав сообщение судьи- докладчика Н.В.Мельникова, исследовав представленные документы и иные материалы, Конституционный Суд Российской Федерации  установил:  1. В соответствии с абзацем вторым пункта 3 статьи 17 Федерального закона от 31 мая 2002 года N 63-ФЗ "Об адвокатской деятельности и адвокатуре в Российской Федерации" не вправе быть представителем в суде, за исключением случаев участия его в процессе в качестве законного представителя, лицо, статус адвоката которого прекращен в связи со вступлением в законную силу приговора суда о признании адвоката виновным в совершении умышленного преступления, а равно по следующим основаниям: неисполнение или ненадлежащее исполнение адвокатом своих профессиональных обязанностей перед доверителем, нарушение адвокатом норм кодекса профессиональной этики адвоката, незаконное использование и (или) разглашение информации, связанной с оказанием адвокатом квалифицированной юридической помощи своему доверителю, либо систематическое несоблюдение установленных законодательством Российской Федерации требований к адвокатскому запросу.  Определением Раздольненского районного суда Республики Крым от 11 июня 2021 года, оставленным без изменения апелляционным определением Верховного Суда Республики Крым от 6 сентября 2021 года, исковое заявление, поданное гражданином С.Г.Шалавиным в качестве представ
аров населению для личного потребления или использования в домашнем  хозяйстве. Стоимость товаров, проданных (отпущенных) отдельным  категориям населения со скидкой или полностью оплаченных органами  социальной защиты, включается в оборот розничной торговли в полном  объеме. В оборот розничной торговли не включается стоимость товаров,  проданных (отпущенных) из розничной торговой сети юридическим лицам (в  том числе организациям социальной сферы, соцпотребителям и т.п.) и  индивидуальным предпринимателям, а также оборот общественного питания.  Оборот розничной торговли включает данные как по организациям, для  которых эта деятельность является основной, так и по организациям других  видов деятельности, осуществляющим продажу товаров собственного  производства населению через торговые заведения, находящиеся на их  балансе, или с оплатой через свою кассу. Оборот розничной торговли  включает также продажу товаров индивидуальными предпринимателями,  физическими лицами на розничных рынках и ярмарках.  Оборот розничной торговли формируется по данным сплошного  федерального статистического наблюдения за организациями, не  относящимися к субъектам малого предпринимательства, выборочного  обследования малых предприятий розничной торговли (за исключением  микропредприятий), которые проводятся с месячной периодичностью, а также  ежеквартальных выборочных обследований розничных рынков, ежегодных  выборочных обследований индивидуальных предпринимателей и  микропредприятий с распространением полученных данных на генеральную  совокупность объектов наблюдения. Кроме того, в соответствии с  требованиями системы национальных счетов этот показатель досчитывается  на объемы скрытой деятельности.  Индекс физического объема оборота розничной торговли - относительный  показатель, характеризующий изменение оборота розничной торговли в  сравниваемых п ...

# %%
df['Name'][3]
# Out:
# 'Федеральный закон от 21 ноября 2022 г. N 443-ФЗ "О внесении изменений в статью 4 части первой, часть вторую Налогового кодекса Российской Федерации и отдельные законодательные акты Российской Федерации" - Российская газета'

# %%
import re
references_df = pd.DataFrame(columns=['Found_Law_Index', 'Name_Index'])

for i, law_name in enumerate(df['Found_Law_Names']):
    if law_name:
        pattern = re.escape(law_name)
        regex = re.compile(pattern, re.IGNORECASE)
        for j, name in enumerate(df['Name']):
            match = regex.search(name)
            if match:
                references_df.at[i, 'Found_Law_Index'] = i
                references_df.at[i, 'Name_Index'] = j
                break

# %%
references_df[references_df['Name_Index'] == 1]
# Out:
#      Found_Law_Index Name_Index
# 1923            1923          1

# %%
df[df['Name'].str.contains('О связи')]
# Out:
#                                                    Name  \
# 767   Федеральный закон от 7 апреля 2020 г. N 110-ФЗ...
# 965   Федеральный закон от 1 мая 2019 г. N 90-ФЗ "О ...
# 1009  Федеральный закон от 6 июня 2019 г. N 131-ФЗ "...
# 1183  Федеральный закон от 1 мая 2019 г. N 90-ФЗ "О ...
# 1229  Федеральный закон от 27 декабря 2018 г. N 527-...
# 1514  Федеральный закон от 27 декабря 2018 г. N 527-...
# 1550  Федеральный закон от 27 декабря 2018 г. N 527-...
# 1558  Федеральный закон от 27 декабря 2018 г. N 529-...
# 1689  Федеральный закон от 5 декабря 2017 года № 386...
# 1873  Изменения в Закон Российской Федерации "О сред...
# 1973  Изменения в Федеральный закон "О связи" — Росс...
# 2186  Изменения в статью 52 Федерального закона "О с...
#
#                                               Link  \
# 767        https://rg.ru/2020/04/09/svyaz-dok.html
# 965         https://rg.ru/2019/05/07/fz90-dok.html
# 1009         https://rg.ru/2019/06/10/smi-dok.html
# 1689  принять государственный дума ноябрь год одобри...             0
# 1873  принять государственный дума июль год одобрить...             0
# 1973  принять государственный дума июль год одобрить...             0
# 2186  принять государственный дума ноябрь год одобри...             0
#
#          Action Expired  Topic_byName  \
# 767   Изменение     NaN             9
# 965   Изменение     NaN             9
# 1009  Изменение     NaN             9
# 1183  Изменение     NaN             9
# 1229  Изменение     NaN             9
# 1514  Изменение     NaN             9
# 1550  Изменение     NaN             9
# 1558        NaN     NaN             9
# 1689  Изменение     NaN             9
# 1873  Изменение     NaN             9
# 1973  Изменение     NaN             9
# 2186  Изменение     NaN             9
#
#                                         Found_Law_Names                 Author
# 767                                                      Государственной Думой
# 965   О закупках товаров, работ, услуг отдельными ви...  Государственной Думой
# 1009                                                     Государственной Думой
# 1183  О закупках товаров, работ, услуг отдельными ви...  Государственной Думой
# 1229                                                     Государственной Думой
# 1514                                                     Государственной Думой
# 1550                                                     Государственной Думой
# 1558                                                     Государственной Думой
# 1689                                                     Государственной Думой
# 1873                                                     Государственной Думой
# 1973                                                     Государственной Думой
# 2186                                                     Государственной Думой

# %%
df['Name'][767]
# Out:
# 'Федеральный закон от 7 апреля 2020 г. N 110-ФЗ "О внесении изменений в Федеральный закон "О связи" — Российская газета'

# %%
conda install -c conda-forge pyvis
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/portnovaxenia/anaconda3/envs/UDV_Summer_2023
#
#   added / updated specs:
#     - pyvis
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.5.7   |       hf0a4a13_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     importlib-metadata-6.7.0   |     pyha770c72_0          25 KB  conda-forge
#     importlib_metadata-6.7.0   |       hd8ed1ab_0           9 KB  conda-forge
#     jsonpickle-1.5.1           |     pyhd8ed1ab_0          32 KB  conda-forge
#     networkx-3.1               |     pyhd8ed1ab_0         1.4 MB  conda-forge
#     openssl-3.1.1              |       h53f4e23_1         2.1 MB  conda-forge
#     pyvis-0.3.1                |     pyhd8ed1ab_0         506 KB  conda-forge
#     zipp-3.15.0                |     pyhd8ed1ab_0          17 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         4.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   importlib-metadata conda-forge/noarch::importlib-metadata-6.7.0-pyha770c72_0
#   importlib_metadata conda-forge/noarch::importlib_metadata-6.7.0-hd8ed1ab_0
#   jsonpickle         conda-forge/noarch::jsonpickle-1.5.1-pyhd8ed1ab_0
#   networkx           conda-forge/noarch::networkx-3.1-pyhd8ed1ab_0
#   pyvis              conda-forge/noarch::pyvis-0.3.1-pyhd8ed1ab_0
#   zipp               conda-forge/noarch::zipp-3.15.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   openssl               pkgs/main::openssl-3.0.9-h1a28f6b_0 --> conda-forge::openssl-3.1.1-h53f4e23_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.05.30~ --> conda-forge::ca-certificates-2023.5.7-hf0a4a13_0
#   certifi            pkgs/main/osx-arm64::certifi-2023.5.7~ --> conda-forge/noarch::certifi-2023.5.7-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# jsonpickle-1.5.1     | 32 KB     |                                       |   0%
# networkx-3.1         | 1.4 MB    |                                       |   0%
#
# ca-certificates-2023 | 145 KB    |                                       |   0%
#
#
# certifi-2023.5.7     | 149 KB    |                                       |   0%
#
#
#
# importlib_metadata-6 | 9 KB      |                                       |   0%
#
#
#
#
# pyvis-0.3.1          | 506 KB    |                                       |   0%
#
#
#
#
#
# importlib-metadata-6 | 25 KB     |                                       |   0%
#
#
#
#
#
#
# zipp-3.15.0          | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    |                                       |   0%
#
# ca-certificates-2023 | 145 KB    | ####                                  |  11%
#
#
# certifi-2023.5.7     | 149 KB    | ###9                                  |  11%
# networkx-3.1         | 1.4 MB    | 4                                     |   1%
#
# ca-certificates-2023 | 145 KB    | ############2                         |  33%
#
#
# jsonpickle-1.5.1     | 32 KB     | ##################################### | 100%
#
# ca-certificates-2023 | 145 KB    | ########################4             |  66%
#
# ca-certificates-2023 | 145 KB    | ####################################7 |  99%
#
# ca-certificates-2023 | 145 KB    | ##################################### | 100%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | #1                                    |   3%
# networkx-3.1         | 1.4 MB    | #2                                    |   3%
#
#
# certifi-2023.5.7     | 149 KB    | ###################8                  |  54%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ###5                                  |   9%
#
#
# certifi-2023.5.7     | 149 KB    | ##################################### | 100%
#
#
#
#
#
# importlib-metadata-6 | 25 KB     | #######################4              |  63%
#
#
#
#
#
# importlib-metadata-6 | 25 KB     | ##################################### | 100%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | #####8                                |  16%
# networkx-3.1         | 1.4 MB    | ###3                                  |   9%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ########1                             |  22%
#
#
#
#
#
#
# zipp-3.15.0          | 17 KB     | ###################################2  |  95%
#
#
#
#
#
#
# zipp-3.15.0          | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | 2                                     |   1%
#
#
#
# importlib_metadata-6 | 9 KB      | ##################################### | 100%
#
#
#
# importlib_metadata-6 | 9 KB      | ##################################### | 100%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | #########3                            |  25%
# networkx-3.1         | 1.4 MB    | ####1                                 |  11%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ##########5                           |  28%
# networkx-3.1         | 1.4 MB    | #####3                                |  15%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | 5                                     |   1%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #3                                    |   4%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #6                                    |   4%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #9                                    |   5%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ##############                        |  38%
# networkx-3.1         | 1.4 MB    | ######2                               |  17%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##1                                   |   6%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ###############1                      |  41%
# networkx-3.1         | 1.4 MB    | ######6                               |  18%
# networkx-3.1         | 1.4 MB    | #######                               |  19%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##7                                   |   7%
# networkx-3.1         | 1.4 MB    | #######4                              |  20%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | #################5                    |  47%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##9                                   |   8%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ##################7                   |  51%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ###################8                  |  54%
# networkx-3.1         | 1.4 MB    | #######8                              |  21%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###5                                  |  10%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | #####################                 |  57%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###8                                  |  10%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ######################2               |  60%
# networkx-3.1         | 1.4 MB    | ########7                             |  24%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ####3                                 |  12%
# pyvis-0.3.1          | 506 KB    | #######################3              |  63%
# networkx-3.1         | 1.4 MB    | #########1                            |  25%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ####9                                 |  13%
# networkx-3.1         | 1.4 MB    | #########5                            |  26%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ########################5             |  66%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ##########################8           |  73%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #####1                                |  14%
# networkx-3.1         | 1.4 MB    | ##########3                           |  28%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #####4                                |  15%
# networkx-3.1         | 1.4 MB    | ##########7                           |  29%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ############################          |  76%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | #############################2        |  79%
# networkx-3.1         | 1.4 MB    | ###########6                          |  31%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #####7                                |  15%
# networkx-3.1         | 1.4 MB    | ############                          |  33%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ##############################3       |  82%
# networkx-3.1         | 1.4 MB    | ############4                         |  34%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #####9                                |  16%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ################################7     |  88%
# networkx-3.1         | 1.4 MB    | #############7                        |  37%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ######5                               |  18%
# networkx-3.1         | 1.4 MB    | ##############5                       |  39%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ######8                               |  18%
# networkx-3.1         | 1.4 MB    | ##############9                       |  40%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ###################################   |  95%
# networkx-3.1         | 1.4 MB    | ###############3                      |  42%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ####################################2 |  98%
# networkx-3.1         | 1.4 MB    | ###############7                      |  43%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #######                               |  19%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ##################################### | 100%
#
#
#
#
# pyvis-0.3.1          | 506 KB    | ##################################### | 100%
# networkx-3.1         | 1.4 MB    | ################6                     |  45%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #######6                              |  21%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #######9                              |  21%
# networkx-3.1         | 1.4 MB    | #################                     |  46%
# networkx-3.1         | 1.4 MB    | #################4                    |  47%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ########1                             |  22%
# networkx-3.1         | 1.4 MB    | ##################2                   |  49%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ########7                             |  24%
# networkx-3.1         | 1.4 MB    | ###################                   |  52%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ########9                             |  24%
# networkx-3.1         | 1.4 MB    | ###################9                  |  54%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #########5                            |  26%
# networkx-3.1         | 1.4 MB    | ####################7                 |  56%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##########                            |  27%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##########3                           |  28%
# networkx-3.1         | 1.4 MB    | #####################5                |  58%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##########6                           |  29%
# networkx-3.1         | 1.4 MB    | ######################                |  59%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##########9                           |  29%
# networkx-3.1         | 1.4 MB    | ######################4               |  61%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###########4                          |  31%
# networkx-3.1         | 1.4 MB    | ######################8               |  62%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###########7                          |  32%
# networkx-3.1         | 1.4 MB    | #######################6              |  64%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###########9                          |  32%
# networkx-3.1         | 1.4 MB    | ########################              |  65%
# networkx-3.1         | 1.4 MB    | ########################4             |  66%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ############5                         |  34%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ############8                         |  35%
# networkx-3.1         | 1.4 MB    | #########################3            |  68%
# networkx-3.1         | 1.4 MB    | #########################7            |  70%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #############                         |  35%
# networkx-3.1         | 1.4 MB    | ##########################5           |  72%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #############6                        |  37%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #############9                        |  38%
# networkx-3.1         | 1.4 MB    | ###########################4          |  74%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##############1                       |  38%
# networkx-3.1         | 1.4 MB    | #############################         |  79%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##############9                       |  41%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###############2                      |  41%
# networkx-3.1         | 1.4 MB    | #############################8        |  81%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###############5                      |  42%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###############8                      |  43%
# networkx-3.1         | 1.4 MB    | ##############################7       |  83%
# networkx-3.1         | 1.4 MB    | ###############################1      |  84%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ################                      |  43%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ################8                     |  46%
# networkx-3.1         | 1.4 MB    | ################################3     |  88%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #################1                    |  46%
# networkx-3.1         | 1.4 MB    | #################################2    |  90%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #################4                    |  47%
# networkx-3.1         | 1.4 MB    | #################################6    |  91%
# networkx-3.1         | 1.4 MB    | ##################################    |  92%
# networkx-3.1         | 1.4 MB    | ##################################8   |  94%
# networkx-3.1         | 1.4 MB    | ####################################5 |  99%
# networkx-3.1         | 1.4 MB    | ####################################9 | 100%
# networkx-3.1         | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #################7                    |  48%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ####################4                 |  55%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #####################2                |  57%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ######################                |  60%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ######################6               |  61%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #######################1              |  63%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #######################7              |  64%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ########################2             |  66%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ########################8             |  67%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #########################6            |  69%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##########################1           |  71%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###########################2          |  74%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ############################          |  76%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ############################8         |  78%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #############################9        |  81%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##############################8       |  83%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###############################6      |  85%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ################################7     |  88%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | #################################7    |  91%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ##################################8   |  94%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ###################################7  |  97%
#
#
#
#
#
#
#
# openssl-3.1.1        | 2.1 MB    | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyvis.network import Network

# Создаем экземпляр класса Network
graph = Network(height='800px', width='1000px', directed=True)

# Добавляем все узлы в граф
for i, row in df.iterrows():
    graph.add_node(i, title=row['Name'])

# Добавляем связи на основе duplicates_df
for i, row in duplicates_df.iterrows():
    law_index = row['Law Index']
    duplicate_indices = row['Duplicate Indices']
    for duplicate_index in duplicate_indices:
        graph.add_edge(law_index, duplicate_index)

# Добавляем связи на основе references_df
for i, row in references_df.iterrows():
    found_law_index = row['Found_Law_Index']
    name_index = row['Name_Index']
    graph.add_edge(found_law_index, name_index)

# Отображаем граф
graph.show('graph.html')

# %%
from pyvis.network import Network

# Создаем экземпляр класса Network
graph = Network(directed=True)

# Создаем HTML-шаблон для отображения подробной информации о законе
html_template = """
<div style="background-color: #f9f9f9; padding: 10px;">
  <h3>{name}</h3>
  <p>Date: {date}</p>
  <p>Link: <a href="{link}" target="_blank">{link}</a></p>
</div>
"""
color_map = {
    0: 'red',
    1: 'blue',
    2: 'green',
    3: 'yellow',
    4: 'orange',
    5: 'purple',
    6: 'pink',
    7: 'cyan',
    8: 'magenta',
    9: 'black',
    10: 'lightblue',
    11: 'lightgreen',
    12: 'lightgray',
    13: 'darkred',
    14: 'darkblue',
    15: 'darkgreen',
    16: 'darkgray',
    17: 'darkorange',
    18: 'darkcyan',
    19: 'darkpurple'
}

# Добавляем все узлы в граф
for i, row in df.iterrows():
    cluster = row['Topic_byName']
    name = row['Name']
    date = row['Data']
    link = row['Link']
    color = color_map.get(cluster, 'gray') 
    graph.add_node(i, label='', title=html_template.format(name=name, date=date, link=link), color=color)

# Добавляем связи на основе duplicates_df
for i, row in duplicates_df.iterrows():
    law_index = row['Law Index']
    duplicate_indices = row['Duplicate Indices']
    for duplicate_index in duplicate_indices:
        graph.add_edge(law_index, duplicate_index, color='purple')

# Добавляем связи на основе references_df
for i, row in references_df.iterrows():
    found_law_index = row['Found_Law_Index']
    name_index = row['Name_Index']
    graph.add_edge(found_law_index, name_index, color='yellow')


# Отображаем граф
graph.show_buttons(filter_=['nodes'])
graph.show('graph.html')

# %%
duplicates_df
# Out:
#      Law Index Duplicate Indices  \
# 0            0             [266]
# 1            1             [169]
# 2            2             [170]
# 3            3             [171]
# 4            4             [172]
# ..         ...               ...
# 911       2534            [2323]
# 912       2668            [2835]
# 913       2732            [2736]
# 914       2736            [2732]
# 915       2835            [2668]
#
#                                         Duplicate Text
# 0    1. Внести в Указ временно исполняющего обязанн...
# 1    Именем Российской Федерации  Конституционный С...
# 2    В целях обеспечения единства практики применен...
# 3    Принят Государственной Думой 10 ноября 2022 го...
# 4    Принят Государственной Думой 10 ноября 2022 го...
# ..                                                 ...
# 911  Основные показатели социально-экономического п...
# 912  Зарегистрирован в Минюсте РФ 29 января 2010 г....
# 913  В соответствии с пунктом 5 статьи 181 Федераль...
# 914  В соответствии с пунктом 5 статьи 181 Федераль...
# 915  Зарегистрирован в Минюсте РФ 20 января 2009 г....
#
# [916 rows x 3 columns]

# %%
df[df['Name'] == 'Проект федерального закона "О внесении изменений в Федеральный закон "О санитарно-эпидемиологическом благополучии населения" — Российская газета']
# Out:
#                                                   Name  \
# 440  Проект федерального закона "О внесении изменен...
#
#                                                   Link  \
# 440  https://rg.ru/2021/11/12/proekt-fz-koronavirus...
#
#                                                   Text  \
# 440  Статья 1  Внести в Федеральный закон от 30 мар...
#
#                                                Comment        Data  \
# 440  В документе идет речь об ограничениях для посе...  2021-11-12
#
#                                                 Tokens  \
# 440  [статья, внести, федеральный, закон, март, год...
#
#                                      Text_preprocessed  Topic_byText  \
# 440  статья внести федеральный закон март год благо...             0
#
#         Action Expired  Topic_byName Found_Law_Names  \
# 440  Изменение     NaN             9
#
#                                         Author  \
# 440  Главным государственным санитарным врачом
#
#                                             Main_Title
# 440  Проект федерального закона О санитарно-эпидеми...
